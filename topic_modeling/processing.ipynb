# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import StratifiedKFold
from sklearn.decomposition import NMF
from scipy.special import kl_div
import pandas as pd
import numpy as np
import math

with open("TREC/texts.txt", "r", encoding="utf-8") as f:
    lines = [line.strip() for line in f if line.strip()]  

df = pd.DataFrame(lines, columns=["text"])

# %%
print(df.describe)
print(df.info())
print(df.head())
# Out:
# <bound method NDFrame.describe of                                                    text
# 0     How did serfdom develop in and then leave Russ...
# 1      What films featured the character Popeye Doyle ?
# 2     How can I find a list of celebrities ' real na...
# 3     What fowl grabs the spotlight after the Chines...
# 4                       What is the full form of .com ?
# ...                                                 ...
# 5947             Who was the 22nd President of the US ?
# 5948             What is the money they use in Zambia ?
# 5949                          How many feet in a mile ?
# 5950                What is the birthstone of October ?
# 5951                                   What is e-coli ?
#
# [5952 rows x 1 columns]>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5952 non-null   object
# dtypes: object(1)
# memory usage: 46.6+ KB
# None
#                                                 text
# 0  How did serfdom develop in and then leave Russ...
# 1   What films featured the character Popeye Doyle ?
# 2  How can I find a list of celebrities ' real na...
# 3  What fowl grabs the spotlight after the Chines...
# 4                    What is the full form of .com ?

# %% [markdown]
# ### NMF (Non-negative matrix factorization)
#
# Resources: https://medium.com/codex/what-is-non-negative-matrix-factorization-nmf-32663fb4d65,
# https://medium.com/voice-tech-podcast/topic-modelling-using-nmf-2f510d962b6e
#
# Theres a bit of math used in NMF explained below:

# %% [markdown]
# ### Kullback-Leibler Divergence (elementwise):
#
# kl_div(x, y)
#
# if x > 0 and y > 0:
#     x log (x/y) - x + y
#
# if x = 0 and y >= 0:
#     y
#
# else:
#     nfinity

# %%
# Saw this implementation in Medium: https://medium.com/voice-tech-podcast/topic-modelling-using-nmf-2f510d962b6e
def kv_div(x, y):
    return np.sum(x[i] * math.log2(x[i] / y[i]) for i in range(len(x)))

# %% [markdown]
# There's also the Frobenius Norm or Euclidean Norm (if you need the formula, make a web search)

# %%
frobenius_norm = lambda x : np.linalg.norm(x)

# %% [markdown]
# Optimization is needed to improve model:

# %% [markdown]
# ### Two types of optimizations present in Scikit learn:
# Coordinate Descent Solver
# Multiplicative update Solver

# %% [markdown]
# ## Using tf-idf on the data:

# %%
vectorizer = TfidfVectorizer(max_features=1500, min_df=10, stop_words='english')
X = vectorizer.fit_transform(df['text'])
words = np.array(vectorizer.get_feature_names_out())

print(X)
print(words)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9774 stored elements and shape (5952, 407)>
#   Coords	Values
#   (0, 108)	1.0
#   (1, 68)	1.0
#   (2, 219)	0.6139327599674049
#   (2, 303)	0.5772910008261286
#   (2, 254)	0.5383508768488926
#   (3, 74)	0.8223115885946162
#   (3, 404)	0.5690374779072103
#   (4, 148)	0.6790684458447013
#   (4, 86)	0.7340749592909855
#   (6, 108)	0.31654393499346684
#   (6, 358)	0.5268021683515133
#   (6, 28)	0.5244917740004745
#   (6, 339)	0.5892264349508014
#   (7, 269)	1.0
#   (9, 268)	0.6708318344556677
#   (9, 388)	0.7416094995891325
#   (10, 47)	1.0
#   (11, 369)	1.0
#   (13, 200)	1.0
#   (15, 345)	0.599547748026181
#   (15, 44)	0.800338989326857
#   (16, 108)	1.0
#   (20, 102)	0.7523895114804765
#   (20, 103)	0.6587184702239416
#   (22, 131)	1.0
#   :	:
#   (5932, 334)	1.0
#   (5933, 148)	1.0
#   (5934, 201)	0.624782260772983
#   (5934, 154)	0.7807990308801622
#   (5936, 307)	0.6502980527329315
#   (5936, 310)	0.7596791708423744
#   (5938, 388)	0.6627856184300285
#   (5938, 204)	0.5675510527146649
#   (5938, 77)	0.4884680404742978
#   (5939, 246)	0.6989557432915479
#   (5939, 132)	0.7151649242795399
#   (5940, 154)	1.0
#   (5941, 108)	0.3654637370137517
#   (5941, 232)	0.5780984322852053
#   (5941, 143)	0.7295467493706836
#   (5944, 384)	1.0
#   (5945, 108)	0.38352183939881684
#   (5945, 404)	0.5297895598024577
#   (5945, 343)	0.756461513249991
#   (5946, 383)	1.0
#   (5947, 292)	1.0
#   (5948, 245)	0.7288341766365415
#   (5948, 378)	0.6846902533018375
#   (5949, 139)	0.6912896742461468
#   (5949, 241)	0.7225777371886407
# ['10' '15' '1984' 'abbreviation' 'acid' 'actor' 'actress' 'address'
#  'africa' 'african' 'age' 'air' 'airport' 'alaska' 'america' 'american'
#  'americans' 'animal' 'animals' 'answers' 'appear' 'area' 'art'
#  'australia' 'author' 'average' 'baby' 'ball' 'baseball' 'basketball'
#  'battle' 'bear' 'beer' 'begin' 'berlin' 'best' 'bible' 'big' 'biggest'
#  'birth' 'black' 'blood' 'blue' 'board' 'boasts' 'body' 'book' 'born'
#  'bowl' 'boy' 'bridge' 'british' 'brothers' 'building' 'built' 'business'
#  'california' 'called' 'canada' 'capital' 'car' 'card' 'cards' 'cartoon'
#  'caused' 'causes' 'center' 'century' 'character' 'charles' 'chemical'
#  'child' 'children' 'china' 'chinese' 'christmas' 'cities' 'city' 'civil'
#  'claim' 'cnn' 'code' 'cold' 'college' 'color' 'colors' 'com' 'come'
#  'comedian' 'comic' 'common' 'company' 'computer' 'contains' 'continent'
#  'cost' 'countries' 'country' 'county' 'craft' 'created' 'cross' 'date'
#  'day' 'death' 'definition' 'department' 'dick' 'did' 'die' 'died'
#  'difference' 'different' 'director' 'discovered' 'disease' 'does' 'dog'
#  'drink' 'dubbed' 'earth' 'east' 'eat' 'end' 'england' 'english' 'europe'
#  'european' 'fame' 'famed' 'family' 'famous' 'far' 'fast' 'fastest'
#  'father' 'favorite' 'fear' 'features' 'feet' 'female' 'film' 'flag'
#  'flight' 'fly' 'following' 'food' 'football' 'form' 'fought' 'founded'
#  'french' 'game' 'games' 'gas' 'general' 'george' 'germany' 'girl' 'god'
#  'gold' 'golf' 'good' 'great' 'greek' 'group' 'hair' 'happened' 'head'
#  'held' 'high' 'highest' 'history' 'hit' 'hitler' 'hole' 'home' 'horse'
#  'house' 'human' 'ice' 'ii' 'indian' 'indians' 'information' 'instrument'
#  'international' 'internet' 'introduced' 'invented' 'island' 'islands'
#  'jack' 'jackson' 'james' 'japan' 'japanese' 'john' 'kennedy' 'kentucky'
#  'killed' 'kind' 'king' 'know' 'known' 'lake' 'language' 'largest' 'latin'
#  'law' 'lawyer' 'leader' 'league' 'letter' 'letters' 'life' 'light' 'like'
#  'line' 'list' 'little' 'live' 'lived' 'lives' 'located' 'london' 'long'
#  'longest' 'los' 'love' 'main' 'major' 'make' 'makes' 'man' 'married'
#  'marvel' 'mean' 'meaning' 'member' 'men' 'mile' 'miles' 'minister'
#  'mississippi' 'money' 'moon' 'mother' 'mount' 'mountain' 'movie' 'music'
#  'musical' 'named' 'names' 'national' 'need' 'new' 'newspaper' 'nickname'
#  'night' 'nixon' 'north' 'novel' 'nuclear' 'number' 'ocean' 'office' 'old'
#  'oldest' 'olympic' 'organization' 'origin' 'original' 'originate' 'paper'
#  'park' 'people' 'percentage' 'person' 'place' 'planet' 'plant' 'play'
#  'played' 'player' 'point' 'pope' 'popular' 'population' 'portrayed'
#  'power' 'president' 'prime' 'prince' 'prize' 'produce' 'produced'
#  'product' 'queen' 'radio' 'randy' 'rate' 'real' 'record' 'red' 'richard'
#  'river' 'rock' 'role' 'runs' 'russian' 'said' 'san' 'saw' 'say' 'school'
#  'sea' 'second' 'series' 'served' 'seven' 'ship' 'shot' 'singer' 'singing'
#  'sioux' 'size' 'soft' 'soldiers' 'son' 'song' 'south' 'soviet' 'space'
#  'spanish' 'species' 'sport' 'sports' 'st' 'stand' 'star' 'starred'
#  'start' 'started' 'state' 'states' 'steven' 'store' 'story' 'street'
#  'strip' 'sun' 'super' 'symbol' 'tall' 'tallest' 'tax' 'team' 'television'
#  'tell' 'temperature' 'tennis' 'term' 'texas' 'thing' 'time' 'times'
#  'title' 'travel' 'tree' 'tuberculosis' 'tv' 'type' 'types' 'union'
#  'united' 'university' 'use' 'used' 'vietnam' 'war' 'washington' 'water'
#  'way' 'web' 'website' 'went' 'west' 'white' 'wife' 'william' 'win' 'wine'
#  'woman' 'women' 'won' 'word' 'words' 'work' 'world' 'worth' 'write'
#  'wrote' 'year' 'years' 'york']

# %% [markdown]
# I'll be using Scikit implementation of NMF:

# %%
nmf = NMF(n_components=10, solver="mu")
W = nmf.fit_transform(X)
H = nmf.components_

for i, topic in enumerate(H):
      print("Topic {}: {}".format(i + 1, ",".join([str(x) for x in words[topic.argsort()[-3:]]])))
# Out:
# Topic 1: stand,mean,does
# Topic 2: die,year,did
# Topic 3: largest,origin,country
# Topic 4: war,largest,world
# Topic 5: cold,food,fear
# Topic 6: united,states,president
# Topic 7: airport,largest,city
# Topic 8: new,year,state
# Topic 9: group,island,called
# Topic 10: live,invented,people

# %% [markdown]
# The original LabPi docs also teached BERTopic, but I couldn't use it for some reason
